# %% [markdown]
# # CSV Ploting Sample

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

df  = pd.read_csv("./00_sample/result.csv")
df2 = pd.read_csv("group9.csv")
df  = df.loc[:, ["IPID", "TTL","SRCIP", "DSTIP", "SPORT", "TSEQ", "WINDS"]]
#print(df2.loc[:, ["DSTIP"]])
#print(df2)

# %%
#Seaborn Pairplot
#sns_plot = sns.pairplot(data=df, corner=True)
#sns_plot.savefig("group9.png")
#plt.clf()
#plt.show()

# %%
#df2 = df2.head(10)
#del df2["IPID"]
#del df2["SRCIP"]
#print(df2)

# %% [markdown]
# # DSTIPとTSEQを削除して、残りのフィールドでプロットするとうまくいく！

# %%
sns_plot = sns.pairplot(data=df2, corner=True)

# %%
#plt.scatter
plt.scatter(df2['DSTIP'], df2['TSEQ'], s = 5, label = "testing")

#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 20, c = 'red', label = 'Centroids')
plt.title('Mapping Clustering Result')
plt.xlabel('DSTIP')
plt.ylabel('TSEQ')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=10)
plt.show()

# %%
# Ploting with heatmaping
